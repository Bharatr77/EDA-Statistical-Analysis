# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 1)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual (0 = Male, 1 = Female)
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Understand the Dataset](#data)**
# 2. **[Measures of Central Tendency](#ct)**
# 3. **[Measures of Dispersion](#md)**
# 4. **[Distribution of the Data](#dist)**
# 5. **[Skewness and kurtosis](#sk)**
# 6. **[Correlation](#corr)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here

import seaborn as sns
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# **Load the adults income dataset and print first five observations**

# %%
# type your code here

df_income = pd.read_csv('adult_income.csv')
df_income.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race  sex  capital.gain  capital.loss  \
# 0                  ?  Not-in-family  White    1             0          4356
# 1    Exec-managerial  Not-in-family  White    1             0          4356
# 2                  ?      Unmarried  Black    1             0          4356
# 3  Machine-op-inspct      Unmarried  White    1             0          3900
# 4     Prof-specialty      Own-child  White    1             0          3900
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# ...

# %%
pd.read_csv('adult_income.csv')
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="data"> </a>
# ## 1. Understand the Dataset

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Find out the numerical and categorical variables in the data. If any variable is wrongly identified, do the needful
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

df_income.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex                int64
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %% [raw]
# The variables 'age','education_num','sex','fnlwgt','capital.gain','capital.loss'and 'hours.per.week' are numerical variables.All
# the remaining variables are categorical.
#
# As per the data definition, the variable 'sex','education.num' should be categorical,which is wrongly interpreted as numerical.
# so change the variable data type to 'object'

# %%
df_income['sex']=df_income['sex'].astype('object')
df_income['education_num']=df_income['education.num'].astype('object')

# %%
df_income.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# education_num     object
# dtype: object

# %% [markdown]
# <a id="ct"> </a>
# ## 2. Measures of Central Tendency

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. What is the average age of males and females in the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_income.groupby('sex')['age'].mean()
# Out:
# sex
# 0    39.433547
# 1    36.858230
# Name: age, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. What is the value under which 95% of the capital gain would lie? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_income['capital.gain'].quantile(0.95)
# Out:
# 5013.0

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Identify the qualification of most of the individuals </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_income['education'].mode()
# Out:
# 0    HS-grad
# Name: education, dtype: object

# %%
df_income['education'].value_counts()
# Out:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Find the middle most observation of age for different working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_income.groupby('workclass')['age'].median()
# Out:
# workclass
# ?                   35.0
# Federal-gov         43.0
# Local-gov           41.0
# Never-worked        18.0
# Private             35.0
# Self-emp-inc        45.0
# Self-emp-not-inc    44.0
# State-gov           39.0
# Without-pay         57.0
# Name: age, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Compare the mean and trimmed mean of capital gain and comment on the presence of outliers</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(15,8))
sns.boxplot(df_income['capital.gain'])

plt.title('Distributuion of the variable (capital.gain)',fontsize = 15)
plt.xlabel('capital_gain',fontsize=15)

plt.show()

# %%
# calculate the mean

print('mean', df_income['capital.gain'].mean())

# calculate the trimmed_mean 
from scipy.stats import trim_mean

# proportiontocut =0.01 cut the 1% data from both tails 
print('trimmed_mean',trim_mean(df_income['capital.gain'],proportiontocut=0.01))
# Out:
# mean 1077.6488437087312
# trimmed_mean 493.7085331077058

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. What is the percentage of the Asian-Pac-Islander race people in the data? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_income['race'].value_counts()/df_income.shape[0]*100
# Out:
# race
# White                 85.427352
# Black                  9.594300
# Asian-Pac-Islander     3.190934
# Amer-Indian-Eskimo     0.955130
# Other                  0.832284
# Name: count, dtype: float64

# %%
df_income['race'].value_counts(normalize =True)*100
# Out:
# race
# White                 85.427352
# Black                  9.594300
# Asian-Pac-Islander     3.190934
# Amer-Indian-Eskimo     0.955130
# Other                  0.832284
# Name: proportion, dtype: float64

# %% [markdown]
# <a id="md"> </a>
# ## 3. Measures of Dispersion

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Which occupation has more variability in the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

df_income.groupby('occupation')['hours.per.week'].var()
# Out:
# occupation
# ?                    225.317543
# Adm-clerical          91.964888
# Armed-Forces         198.000000
# Craft-repair          81.939394
# Exec-managerial      123.412395
# Farming-fishing      299.987814
# Handlers-cleaners    111.946104
# Machine-op-inspct     57.648955
# Other-service        161.442544
# Priv-house-serv      261.939597
# Prof-specialty       157.159186
# Protective-serv      152.072728
# Sales                175.202547
# Tech-support         112.001859
# Transport-moving     161.833503
# Name: hours.per.week, dtype: float64

# %%
# type your code here
df_income.groupby('occupation')['hours.per.week'].std().sort_values(ascending=False)
# Out:
# occupation
# Farming-fishing      17.320156
# Priv-house-serv      16.184548
# ?                    15.010581
# Armed-Forces         14.071247
# Sales                13.236410
# Transport-moving     12.721380
# Other-service        12.706004
# Prof-specialty       12.536315
# Protective-serv      12.331777
# Exec-managerial      11.109113
# Tech-support         10.583093
# Handlers-cleaners    10.580459
# Adm-clerical          9.589833
# Craft-repair          9.052038
# Machine-op-inspct     7.592691
# Name: hours.per.week, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 9. What is the range of the middle 50% of working hours per week?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

IQR = df_income['hours.per.week'].quantile(.75)-df_income['hours.per.week'].quantile(.25)

IQR
# Out:
# 5.0

# %% [raw]
# The middle 50% of the data has a range of 5 working hours.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Are there any variables which can be excluded from further analysis based on their variability?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

df_num = df_income.select_dtypes(include =np.number)
df_num.std()
# Out:
# age                   13.640433
# fnlwgt            105549.977697
# education.num          2.572720
# capital.gain        7385.292085
# capital.loss         402.960219
# hours.per.week        12.358681
# dtype: float64

# %% [raw]
# the standard daviation of none of the variables is near zero.so we shall consider all the variables for further analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Find the percentage of variation in work hours for each workclass. Give an appropriate interpretation</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

mean_wkclass = df_income.groupby('workclass')['hours.per.week'].mean()
sd_wkclass = df_income.groupby('workclass')['hours.per.week'].std()

#compute coefficient of variation

cv =sd_wkclass/mean_wkclass*100
cv.sort_values(ascending = False)
# Out:
# workclass
# Without-pay         53.059084
# ?                   46.711116
# Self-emp-not-inc    37.537713
# State-gov           29.968071
# Self-emp-inc        28.473900
# Private             27.954085
# Local-gov           26.283120
# Federal-gov         21.360037
# Never-worked              NaN
# Name: hours.per.week, dtype: float64

# %% [markdown]
# <a id="dist"> </a>
# ## 4. Distribution of the Data

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Define a function to plot the categories of the variable and find the category with highest frequency</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

cols = list(df_income.select_dtypes(exclude=np.number).columns)
cols
# Out:
# ['workclass',
#  'education',
#  'marital.status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native.country',
#  'income',
#  'education_num']

# %%
 def cat_plots(df,nrows,ncols):
        
   cols = list(df_income.select_dtypes(exclude=np.number).columns)
   fig , ax =plt.subplot(nrows,ncols,figsize=(25,15))
    
   j=1
   for i in cols:
        
    plt.subplot(nrows,ncols,j)
        
    sns.countplot(df.loc[:,i])
    plt.title(i)
    j = j+1
    
plt.tight_layout()
plt.show()

# %%
cat_plots(df_income,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 cat_plots(df_income,3,4)
#
# Cell In[65], line 4, in cat_plots(df, nrows, ncols)
#       1 def cat_plots(df,nrows,ncols):
#       3   cols = list(df_income.select_dtypes(exclude=np.number).columns)
# ----> 4   fig , ax =plt.subplot(nrows,ncols,figsize=(25,15))
#       6   j=1
#       7   for i in cols:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Is there any variable which is normally distributed?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_num = df_income.select_dtypes(exclude ='object')
df_num.skew()
# Out:
# age                0.558743
# fnlwgt             1.446980
# education.num     -0.311676
# capital.gain      11.953848
# capital.loss       4.594629
# hours.per.week     0.222241
# dtype: float64

# %%
f_num = df_income.select_dtypes(exclude ='object')
df_num.kurt()
# Out:
# age                -0.166127
# fnlwgt              6.218811
# education.num       0.623444
# capital.gain      154.799438
# capital.loss       20.376802
# hours.per.week      2.916782
# dtype: float64

# %%
sns.distplot(df_income['hours.per.week'])
plt.show()
# Out:
# C:\Users\radhika rawat\AppData\Local\Temp\ipykernel_52548\2208839832.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_income['hours.per.week'])

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Identify the working class for most of the population in the data</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

plt.figure(figsize=(15,8))

sns.countplot(x=df_income['workclass'])

plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. For how much time are most of the individuals working per week?
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_income['hours.per.week'].describe()
# Out:
# count    32561.000000
# mean        40.431344
# std         12.358681
# min          0.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours.per.week, dtype: float64

# %% [markdown]
# <a id="sk"> </a>
# ## 5. Skewness and kurtosis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Is there any negatively skewed feature. Support your answer with a metric and the plot</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_num = df_income.select_dtypes(include =np.number)
df_num.skew()
# Out:
# age                0.558743
# fnlwgt             1.446980
# education.num     -0.311676
# capital.gain      11.953848
# capital.loss       4.594629
# hours.per.week     0.222241
# dtype: float64

# %% [raw]
# the variable 'education.num' has a negative coefficient of skewness.let us plot the distribution of variable and check
# the skewness

# %%
plt.figure(figsize=(15,8))

sns.distplot(a=df_income['education.num'],hist = False)

plt.show()
# Out:
# C:\Users\radhika rawat\AppData\Local\Temp\ipykernel_52548\2002832274.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=df_income['education.num'],hist = False)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Find the kurtosis of all the variables, and give appropriate interpretation</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

df_num = df_income.select_dtypes(include =np.number)
df_num.kurt()
# Out:
# age                -0.166127
# fnlwgt              6.218811
# education.num       0.623444
# capital.gain      154.799438
# capital.loss       20.376802
# hours.per.week      2.916782
# dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Identify the presence of extreme values in age using visualization techniques
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

plt.figure(figsize=(15,8))

sns.boxplot(x=df_income['age'],showmeans = True)

plt.show()

# %% [markdown]
# <a id="corr"> </a>
# ## 6. Correlation

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Is there any effect of age on the working hours of a person?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

df_income[['age','hours.per.week']].corr()
# Out:
#                      age  hours.per.week
# age             1.000000        0.069311
# hours.per.week  0.069311        1.000000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Visualize the upper triangular correlation matrix</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_num = df_income.select_dtypes(include =np.number)
sns.heatmap(df_num.corr(),mask=np.tril(df_num.corr()),annot=True,cmap='plasma')
plt.show()
